# %% [markdown]
# # AgenticLS clean-runtime smoke test
# Run this notebook from a fresh Colab runtime after cloning the repository.

# %%
# !pip install -e '.[dev]'
# !python -m pytest -q
# !python -m agenticls_auditor.smoke --config config/experiment.yaml
